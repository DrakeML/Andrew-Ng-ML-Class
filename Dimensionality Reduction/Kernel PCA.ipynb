# %% [markdown]
# # Kernel PCA

# %%
from sklearn.datasets import make_circles
# Out:
# C:\Users\Drake\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\Drake\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
from sklearn.decomposition import PCA, KernelPCA

# %%
import numpy as np
import pandas as pd
# Out:
# C:\Users\Drake\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
np.random.seed(0)

# %%
X,y = make_circles(n_samples=400, factor=0.3, noise=0.05)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('whitegrid')
# Out:
# C:\Users\Drake\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)
# C:\Users\Drake\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
plt.figure()
plt.scatter(X[:,0], X[:,1]);

# %%
kpca = KernelPCA(kernel = 'rbf', fit_inverse_transform=True, gamma=10)

# %%
X_kpca = kpca.fit_transform(X)
X_back = kpca.inverse_transform(X_kpca)

# %%
pca = PCA()
X_pca = pca.fit_transform(X)

# %%
plt.figure()
plt.title('Original Space')
reds = y == 0
blues = y == 1

plt.scatter(X[reds, 0], X[reds, 1], c='red', s=20, edgecolor='k')

plt.scatter(X[blues, 0], X[blues, 1], c='blue', s=20, edgecolor='k')

plt.xlabel('$x_1$')
plt.ylabel('$x_2$');

# %%
plt.scatter(X_pca[reds, 0], X_pca[reds, 1], c='red', s=20, edgecolor='k')
plt.scatter(X_pca[blues, 0], X_pca[blues, 1], c='blue', s=20, edgecolor='k')

plt.title('Projection by PCA')
plt.xlabel('1st Principle Component')
plt.ylabel('2nd Principle Component');

# %%
plt.scatter(X_kpca[reds, 0], X_kpca[reds, 1], c='red', s=20, edgecolor='k')
plt.scatter(X_kpca[blues, 0], X_kpca[blues, 1], c='blue', s=20, edgecolor='k')

plt.title('Projection by KPCA')
plt.xlabel('1st Principle Component in Space Induced by $\phi$')
plt.ylabel('2nd Principle Component');
